# %%
import pandas as pd

#Imported the fbi data and the data had NAN and was not organized correctly

fbi_data = pd.read_csv('fbi_data.csv', encoding="ISO-8859-1")
fbi_data
# Out:
#                                                Table 1               \
# 0                           Crime in the United States          NaN
# 1    by Volume and Rate per 100,000 Inhabitants, 19...          NaN
# 2                                                 Year  Population1
# 3                                                 1997  267,783,607
# 4                                                 1998  270,248,003
# 5                                                 1999  272,690,813
# 6                                                 2000  281,421,906
# 7                                                20015  285,317,559
# 8                                                 2002  287,973,924
# 9                                                 2003  290,788,976
# 10                                                2004  293,656,842
# 11                                                2005  296,507,061
# 12                                                2006  299,398,484
# ...

# %%
# I removed the NaN and in column and rows. 
# Placed the row as the headers
#reset index

new_header = fbi_data.iloc[2]
header = fbi_data[1:]
header_set = fbi_data.rename(columns = new_header)
remove_nan_row = header_set.dropna(thresh=3)
remove_nan_column = remove_nan_row.dropna(axis=1, how='any')
tidy_version = remove_nan_column.drop(remove_nan_column.index[0]).reset_index(drop=True)
tidy_version
# Out:
#      Year  Population1 Violent\rcrime2 Violent \rcrime \rrate   \
# 0    1997  267,783,607       1,636,096                   611.0
# 1    1998  270,248,003       1,533,887                   567.6
# 2    1999  272,690,813       1,426,044                   523.0
# 3    2000  281,421,906       1,425,486                   506.5
# 4   20015  285,317,559       1,439,480                   504.5
# 5    2002  287,973,924       1,423,677                   494.4
# 6    2003  290,788,976       1,383,676                   475.8
# 7    2004  293,656,842       1,360,088                   463.2
# 8    2005  296,507,061       1,390,745                   469.0
# 9    2006  299,398,484       1,435,123                   479.3
# 10   2007  301,621,157       1,422,970                   471.8
# 11   2008  304,059,724       1,394,461                   458.6
# 12   2009  307,006,550       1,325,896                   431.9
# 13   2010  309,330,219       1,251,248                   404.5
# ...
