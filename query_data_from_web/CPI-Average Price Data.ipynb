# %%
import pandas as pd
import matplotlib.pyplot as plt

#imported data and recieved NaN and columns below header

gas_price = pd.read_csv('CPI-Average Price Data.csv')
gas_price
# Out:
#    CPI-Average Price Data                                         Unnamed: 1  \
# 0     Original Data Value                                                NaN
# 1                     NaN                                                NaN
# 2              Series Id:                                       APU000074714
# 3           Series Title:  Gasoline, unleaded regular, per gallon/3.785 l...
# 4                   Area:                                  U.S. city average
# 5                   Item:  Gasoline, unleaded regular, per gallon/3.785 l...
# 6                  Years:                                       2008 to 2018
# 7                     NaN                                                NaN
# 8                    Year                                                Jan
# 9                    2008                                              3.047
# 10                   2009                                              1.787
# ...

# %%
#Placed row as Header
#Removed the NaN from column and rows
# Replcaed NaN in last bottom row with four zeros
# Reset index

new_header = gas_price.iloc[8]
header = new_header[1:]
header_set = gas_price.rename(columns = new_header)
remove_nan_row = header_set.dropna(thresh=3)
index_reset = remove_nan_row.fillna(value=0).reset_index(drop=True)
tidy_results = index_reset.drop(gas_price.index[0])
tidy_results
# Out:
#     Year    Jan    Feb    Mar    Apr    May    Jun    Jul    Aug    Sep  \
# 1   2008  3.047  3.033  3.258  3.441  3.764  4.065  4.090  3.786  3.698
# 2   2009  1.787  1.928  1.949  2.056  2.265  2.631  2.543  2.627  2.574
# 3   2010  2.731  2.659  2.780  2.858  2.869  2.736  2.736  2.745  2.704
# 4   2011  3.091  3.167  3.546  3.816  3.933  3.702  3.654  3.630  3.612
# 5   2012  3.399  3.572  3.868  3.927  3.792  3.552  3.451  3.707  3.856
# 6   2013  3.351  3.693  3.735  3.590  3.623  3.633  3.628  3.600  3.556
# 7   2014  3.320  3.364  3.532  3.659  3.691  3.695  3.633  3.481  3.403
# 8   2015  2.110  2.249  2.483  2.485  2.775  2.832  2.832  2.679  2.394
# 9   2016  1.967  1.767  1.958  2.134  2.264  2.363  2.225  2.155  2.208
# 10  2017  2.351  2.299  2.323  2.418  2.386  2.337  2.281  2.374  2.630
# 11  2018  2.539  2.575  2.572  2.737  2.907  2.914  2.873  2.862      0
#
#       Oct    Nov    Dec
# 1   3.173  2.151  1.689
# 2   2.561  2.660  2.621
# 3   2.795  2.852  2.985
# ...
